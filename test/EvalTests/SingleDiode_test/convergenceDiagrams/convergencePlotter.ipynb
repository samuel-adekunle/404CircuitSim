# %%
import pandas as pd
import matplotlib as py
import os

head = {'Step','Voltage Guess','Voltage Error'}
a = pd.read_csv("./260usConvergence.csv",delimiter=',')
a.columns = head

a.plot(x='it',y={'Voltage Guess','Voltage Error'})
print(a)
# Out:
# it   vErrVec    vGuess
# 0      1  0.021888  4.938680
# 1      2  0.046582  4.913980
# 2      3  0.071151  4.889410
# 3      4  0.095599  4.864970
# 4      5  0.119923  4.840640
# ..   ...       ...       ...
# 994  995  0.690125  0.033657
# 995  996  0.690140  0.033489
# 996  997  0.690156  0.033321
# 997  998  0.690171  0.033155
# 998  999  0.690186  0.032989
#
# [999 rows x 3 columns]
